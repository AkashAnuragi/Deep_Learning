# %%
import pandas as pd

# %%
df = pd.read_csv('../dataset/Hotel_Reviews.csv')

# %%
df.shape
# Out:
# (515738, 17)

# %%
df.head(1)
# Out:
#                                        Hotel_Address  \
# 0   s Gravesandestraat 55 Oost 1092 AA Amsterdam ...
#
#    Additional_Number_of_Scoring Review_Date  Average_Score   Hotel_Name  \
# 0                           194    8/3/2017            7.7  Hotel Arena
#
#   Reviewer_Nationality                                    Negative_Review  \
# 0              Russia    I am so angry that i made this post available...
#
#    Review_Total_Negative_Word_Counts  Total_Number_of_Reviews  \
# 0                                397                     1403
#
#                                      Positive_Review  \
# 0   Only the park outside of the hotel was beauti...
#
#    Review_Total_Positive_Word_Counts  \
# 0                                 11
#
#    Total_Number_of_Reviews_Reviewer_Has_Given  Reviewer_Score  \
# 0                                           7             2.9
#
#                                                 Tags days_since_review  \
# ...

# %%
negative = df['Negative_Review'].value_counts().reset_index()
positive = df['Positive_Review'].value_counts().reset_index()

# %%
negative
# Out:
#                                           Negative_Review   count
# 0                                             No Negative  127890
# 1                                                 Nothing   14295
# 2                                                Nothing     4236
# 3                                                 nothing    2225
# 4                                                     N A    1037
# ...                                                   ...     ...
# 330006   No parking Public parking garage is 15 Euro p...       1
# 330007   no trolly or staff to help you take the lugga...       1
# 330008           The hotel looks like 3 but surely not 4        1
# 330009   The ac was useless It was a hot week in vienn...       1
# 330010       I was in 3rd floor It didn t work Free Wife        1
#
# [330011 rows x 2 columns]

# %%
negative.head(2)
# Out:
#   Negative_Review   count
# 0     No Negative  127890
# 1         Nothing   14295

# %%
negative['status'] = 0
positive['status'] = 1

# %%
negative
# Out:
#                                           Negative_Review   count  status
# 0                                             No Negative  127890       0
# 1                                                 Nothing   14295       0
# 2                                                Nothing     4236       0
# 3                                                 nothing    2225       0
# 4                                                     N A    1037       0
# ...                                                   ...     ...     ...
# 330006   No parking Public parking garage is 15 Euro p...       1       0
# 330007   no trolly or staff to help you take the lugga...       1       0
# 330008           The hotel looks like 3 but surely not 4        1       0
# 330009   The ac was useless It was a hot week in vienn...       1       0
# 330010       I was in 3rd floor It didn t work Free Wife        1       0
#
# [330011 rows x 3 columns]

# %%
negative.head(1)
# Out:
#   Negative_Review   count  status
# 0     No Negative  127890       0

# %%
positive.head(1)
# Out:
#   Positive_Review  count  status
# 0     No Positive  35946       1

# %%
negative.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 330011 entries, 0 to 330010
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Negative_Review  330011 non-null  str
#  1   count            330011 non-null  int64
#  2   status           330011 non-null  int64
# dtypes: int64(2), str(1)
# memory usage: 7.6 MB

# %%
positive.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 412601 entries, 0 to 412600
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Positive_Review  412601 non-null  str
#  1   count            412601 non-null  int64
#  2   status           412601 non-null  int64
# dtypes: int64(2), str(1)
# memory usage: 9.4 MB

# %%
negative = negative[negative['count']==1]
positive = positive[positive['count']==1]

# %%
negative.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 323546 entries, 6465 to 330010
# Data columns (total 3 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   Negative_Review  323546 non-null  str
#  1   count            323546 non-null  int64
#  2   status           323546 non-null  int64
# dtypes: int64(2), str(1)
# memory usage: 7.4 MB

# %%
negative.shape
# Out:
# (323546, 3)

# %%
positive.shape
# Out:
# (403184, 3)

# %%
negative = negative.rename(columns={'Negative_Review': 'text'})
positive = positive.rename(columns={'Positive_Review': 'text'})

# %%
negative.head(1)
# Out:
#                                                    text  count  status
# 6465   I am so angry that i made this post available...      1       0

# %%
positive.head(2)
# Out:
#                                                    text  count  status
# 9417   Only the park outside of the hotel was beauti...      1       1
# 9418   No real complaints the hotel was great great ...      1       1

# %%
positive.to_csv('../dataset/positive.csv', index=False)
negative.to_csv('../dataset/negative.csv', index=False)
